# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import json
import numpy as np   # use for mathematical problems
import pandas as pd # use to do task on data frame
import matplotlib.pyplot as plt # use to plot graph
from statsmodels.tsa.seasonal import seasonal_decompose  # use to find components of seasonal decompose
from statsmodels.tsa.stattools import adfuller  # use to check fata is stationary
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf  # USE TO GET P AND Q VALUE 
import  statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from  sklearn.metrics import mean_squared_error  # use to calculate error
from pmdarima.arima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_json('Amazon home&kitchen_jsonfile_new_10perdata.json',orient='split')

# %%
#df.to_csv("C:\channappa\capstone project\home.csv")

# %%
df=df.sort_values(by='Time',ascending=True)

# %%
df2=df.copy()

# %%
df2.shape
# Out:
# (421428, 17)

# %%
df.isnull().sum()
# Out:
# productID             0
# categories            0
# price                 0
# brand                 0
# product_name          0
# reviewerID            0
# reviewerName          0
# overall               0
# review_text           0
# pos_feedback          0
# neg_feedback          0
# rating_class          0
# Time                  0
# tokenized             0
# Polarity              0
# Sentiment             0
# Sentiment_Analysis    0
# dtype: int64

# %%
df.describe()
# Out:
#                price        overall   pos_feedback   neg_feedback  \
# count  421428.000000  421428.000000  421428.000000  421428.000000
# mean       57.522042       4.098019       2.205255       0.416804
# std        80.889853       1.332770      17.223774       2.298147
# min         0.010000       1.000000       0.000000       0.000000
# 25%        14.990000       4.000000       0.000000       0.000000
# 50%        34.990000       5.000000       0.000000       0.000000
# 75%        66.000000       5.000000       1.000000       0.000000
# max       999.990000       5.000000    3756.000000     469.000000
#
#             Polarity      Sentiment
# count  421428.000000  421428.000000
# mean        0.277318       0.921045
# std         0.233937       0.318427
# min        -1.000000       0.000000
# 25%         0.133333       1.000000
# 50%         0.273016       1.000000
# 75%         0.425000       1.000000
# max         1.000000       2.000000

# %%
df.dtypes
# Out:
# productID              object
# categories             object
# price                 float64
# brand                  object
# product_name           object
# reviewerID             object
# reviewerName           object
# overall                 int64
# review_text            object
# pos_feedback            int64
# neg_feedback            int64
# rating_class           object
# Time                   object
# tokenized              object
# Polarity              float64
# Sentiment               int64
# Sentiment_Analysis     object
# dtype: object

# %%
mask = (df['Time'] > '2010-1-1') & (df['Time'] <= '2014-12-31')
df = df.loc[mask]

# %%
df2
# Out:
#           productID                                         categories  \
# 11968    B00002SAO2  home  kitchen artwork posters  prints video ga...
# 40678    B00004RHR6  home  kitchen kitchen  dining kitchen utensils...
# 81949    B00004SY7L  home  kitchen kitchen  dining cookware cookwar...
# 31554    B00004RDCT  home  kitchen kitchen  dining kitchen utensils...
# 55435    B00004S8DX  home  kitchen kitchen  dining cookware cookwar...
# ...             ...                                                ...
# 4211588  B00KILOAXE  home  kitchen kitchen  dining kitchen utensils...
# 4190241  B00IDXGIAC  home  kitchen heating cooling  air quality air...
# 4213356  B00KW1ZDCM  home  kitchen kitchen  dining kitchen utensils...
# 4070554  B00E63THI8  home  kitchen kitchen  dining storage  organiz...
# 4132262  B00FYNXC76  home  kitchen kitchen  dining bakeware candy m...
#
#               price        brand                                product_name  \
# 11968     76.273582          nan
# 40678     51.655678     hoffritz            stainlesssteel manual can opener
# 81949     64.348455    calphalon  commercial hardanodized piece cookware set
# 31554     48.648521  progressive           international cup gravy separator
# 55435     62.080348        meyer           anolon classic piece cookware set
# ...             ...          ...                                         ...
# 4211588   19.950000      vegepal        spiral slicer best quality stainless
# 4190241  417.190000       quirky                    ge aros smart window air
# 4213356    9.990000        ozera                        ice pop molds set of
# 4070554   39.990000     lifeline             wh white stainless steel vacuum
# 4132262    5.630000    cybrtrayd              cybrtrayd l no lolly chocolate
#
#              reviewerID      reviewerName  overall  \
# 11968      AFHJFPWNQDQE   "sir_tripsalot"        5
# 40678     AAE95UYBYNCP6       Betina Chan        4
# 81949     ADGT49GN6CQNJ          S. Bauer        4
# 31554    A20SOBM0RWYPOD              erek        1
# 55435     A3YNKCNKA5HAN  Daniel W. DeLuca        5
# ...                 ...               ...      ...
# 4211588  A3MXNRZDBZVOBY     Margie Jordan        5
# 4190241  A2020EPZ0NLS3E   Kyle Wickersham        5
# 4213356  A351A2418T54US       Lori Parker        5
# 4070554  A2G5QIX8FV6NC0         Steven ET        5
# 4132262    A3BGFNJXRQ1S      Jose cintron        5
#
#                                                review_text  pos_feedback  \
# 11968    wonderful romp through a giganitic ship dougla...             8
# 40678    opens anything and everything hoffritz has a n...            30
# 81949    the best money can buy you cant go wrong with ...             9
# 31554    old technology fat separator once upon a time ...            17
# 55435    best highend nonstick value after experimentin...            43
# ...                                                    ...           ...
# 4211588  boodles of fun i could not wait to get home an...             0
# 4190241  great buy for many reasons i am very satisfied...             0
# 4213356  be mindful of your health for kids seniors and...             0
# 4070554  high quality fast shipping price is competitiv...             0
# 4132262                      five stars i like it its good             0
#
#          neg_feedback rating_class                      Time  \
# 11968               4         good  1999-12-04T00:00:00.000Z
# 40678              12         good  2000-04-24T00:00:00.000Z
# 81949               0         good  2000-05-02T00:00:00.000Z
# 31554              15          bad  2000-05-02T00:00:00.000Z
# 55435               1         good  2000-05-02T00:00:00.000Z
# ...               ...          ...                       ...
# 4211588             0         good  2014-07-23T00:00:00.000Z
# 4190241             2         good  2014-07-23T00:00:00.000Z
# 4213356             0         good  2014-07-23T00:00:00.000Z
# 4070554             0         good  2014-07-23T00:00:00.000Z
# 4132262             0         good  2014-07-23T00:00:00.000Z
#
#                                                  tokenized  Polarity  \
# 11968    ['wonderful', 'romp', 'giganitic', 'ship', 'do...  0.269583
# 40678    ['opens', 'anything', 'everything', 'hoffritz'...  0.275000
# 81949    ['best', 'money', 'buy', 'cant', 'go', 'wrong'...  0.209957
# 31554    ['old', 'technology', 'fat', 'separator', 'upo...  0.025000
# 55435    ['best', 'highend', 'nonstick', 'value', 'expe...  0.387302
# ...                                                    ...       ...
# 4211588  ['boodles', 'fun', 'could', 'wait', 'get', 'ho...  0.215365
# 4190241  ['great', 'buy', 'many', 'reasons', 'satisfied...  0.407143
# 4213356  ['mindful', 'health', 'kids', 'seniors', 'ozer...  0.143403
# 4070554  ['high', 'quality', 'fast', 'shipping', 'price...  0.147500
# 4132262                  ['five', 'stars', 'like', 'good']  0.700000
#
#          Sentiment Sentiment_Analysis
# 11968            1           Positive
# 40678            1           Positive
# 81949            1           Positive
# 31554            1           Positive
# 55435            1           Positive
# ...            ...                ...
# 4211588          1           Positive
# 4190241          1           Positive
# 4213356          1           Positive
# 4070554          1           Positive
# 4132262          1           Positive
#
# [421428 rows x 17 columns]

# %% [markdown]
# ## resampling tge data

# %%
# Convert time object to datetime and create a new column named 'time'
df['Time'] = pd.to_datetime(df['Time'])

df.set_index('Time',inplace=True)

# %%
month=df.resample('w').mean()

# %%
month.isnull().sum()
# Out:
# price           0
# overall         0
# pos_feedback    0
# neg_feedback    0
# Polarity        0
# Sentiment       0
# dtype: int64

# %%
month.shape
# Out:
# (200, 6)

# %%
month.isnull().sum()
# Out:
# price           0
# overall         0
# pos_feedback    0
# neg_feedback    0
# Polarity        0
# Sentiment       0
# dtype: int64

# %%
df.shape
# Out:
# (362585, 16)

# %% [markdown]
# ## calculate time series components

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decompose=seasonal_decompose(month['Sentiment'],period=52)
trend=decompose.trend
seasonal=decompose.seasonal
resid=decompose.resid

# %%
plt.figure(figsize=(20,12))
plt.subplot(4,1,1)
plt.plot(month['Sentiment'],label='original')
plt.title('Actual')
plt.subplot(4,1,2)
plt.plot(trend,label='Trend',color='r')
plt.title('TREND')
plt.subplot(4,1,3)
plt.plot(seasonal,label='Seasonality',color='orange')
plt.title('Seasonal')
plt.subplot(4,1,4)
plt.plot(resid,label='Irregular',color='teal')
plt.title('Residual')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from statsmodels.tsa.stattools import  adfuller

# %%
## check data stationary
def sta(data):
    pvalue=adfuller(data)[1]
    
    if pvalue <0.05:
        ret='data is astationary'
    else:
        ret='data is not stationary'
    return ret

# %%
price=month['Sentiment']
price
# Out:
# Time
# 2010-10-03 00:00:00+00:00    0.882353
# 2010-10-10 00:00:00+00:00    0.899510
# 2010-10-17 00:00:00+00:00    0.914692
# 2010-10-24 00:00:00+00:00    0.886918
# 2010-10-31 00:00:00+00:00    0.910891
#                                ...
# 2014-06-29 00:00:00+00:00    0.925357
# 2014-07-06 00:00:00+00:00    0.967818
# 2014-07-13 00:00:00+00:00    0.963445
# 2014-07-20 00:00:00+00:00    0.974599
# 2014-07-27 00:00:00+00:00    0.944310
# Freq: W-SUN, Name: Sentiment, Length: 200, dtype: float64

# %%
sta(price)
# Out:
# 'data is not stationary'

# %%
diff=price-price.shift(1)
diff.dropna(inplace=True)

# %%
sta(diff)
# Out:
# 'data is astationary'

# %%
len(price)
# Out:
# 200

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_acf(month.Sentiment,lags=30)
plot_pacf(month.Sentiment,lags=30)

# %% [markdown]
# q=11
# p=5

# %%
l=int(0.7*len(month.Sentiment))
train=month.Sentiment.iloc[:l]
test=month.Sentiment.iloc[l:]
print(train.shape,test.shape)
# Out:
# (140,) (60,)

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Build a ARIMA model, build a function for checking the best model

# %%
from pmdarima import auto_arima

# %%
def arima_model(data):
    
    list1 = []
    for p in range(5):
        
        for q in range(13):
            list1.append((p,1,q))
           
    model = []
    for i in list1:
        
        m=ARIMA(train,order=i).fit()
        model.append(m)
       
    forecast = []
    for v in model:
        
        f=v.predict(0,len(test)-1)
        forecast.append(f)
       
    RMSE=[]
    for a in forecast[0:]:
        
        rmse = mean_squared_error(test,a,squared=False)
        RMSE.append(round(rmse,3))
    df1=pd.DataFrame()
    df1['list']=list1
    df1['model']=model
    df1['forecast']=forecast
    df1['rmse']=RMSE
   
       
    return(df1)

# %%
dff=arima_model(train)

# %%
dff[dff.rmse==dff.rmse.min()]
# Out:
#           list                                              model  \
# 0    (0, 1, 0)  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 1    (0, 1, 1)  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 2    (0, 1, 2)  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 3    (0, 1, 3)  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 4    (0, 1, 4)  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# ..         ...                                                ...
# 60   (4, 1, 8)  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 61   (4, 1, 9)  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 62  (4, 1, 10)  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 63  (4, 1, 11)  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
# 64  (4, 1, 12)  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...
#
#                                              forecast   rmse
# 0   Time
# 2010-10-03 00:00:00+00:00    0.000000
# 201...  0.121
# 1   Time
# 2010-10-03 00:00:00+00:00    0.000000
# 201...  0.121
# 2   Time
# 2010-10-03 00:00:00+00:00    0.000000
# 201...  0.121
# 3   Time
# 2010-10-03 00:00:00+00:00    0.000000
# 201...  0.121
# 4   Time
# 2010-10-03 00:00:00+00:00    0.000000
# 201...  0.121
# ..                                                ...    ...
# 60  Time
# 2010-10-03 00:00:00+00:00    0.000000
# 201...  0.121
# 61  Time
# 2010-10-03 00:00:00+00:00    0.000000
# 201...  0.121
# 62  Time
# 2010-10-03 00:00:00+00:00    0.000000
# 201...  0.121
# 63  Time
# 2010-10-03 00:00:00+00:00    0.000000
# 201...  0.121
# 64  Time
# 2010-10-03 00:00:00+00:00    0.000000
# 201...  0.121
#
# [65 rows x 4 columns]

# %%
from pmdarima import auto_arima

# %%
m1 = auto_arima(month['Sentiment'],start_p=0,max_p=5, start_q=0,max_q=12, seasonal=True, trace=True)
print(m1.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-1150.986, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-1191.161, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-1217.480, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-1152.877, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-1217.329, Time=0.39 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-1216.062, Time=0.12 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-1214.543, Time=0.72 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-1218.210, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-1217.881, Time=0.17 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-1217.568, Time=0.31 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-1192.841, Time=0.21 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-1215.184, Time=0.38 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 2.773 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  200
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                 611.105
# Date:                Tue, 13 Dec 2022   AIC                          -1218.210
# Time:                        13:23:31   BIC                          -1211.624
# Sample:                    10-03-2010   HQIC                         -1215.544
#                          - 07-27-2014
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7026      0.043    -16.291      0.000      -0.787      -0.618
# sigma2         0.0001   1.11e-05     11.292      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.65   Jarque-Bera (JB):                 4.01
# Prob(Q):                              0.42   Prob(JB):                         0.13
# Heteroskedasticity (H):               0.62   Skew:                             0.12
# Prob(H) (two-sided):                  0.05   Kurtosis:                         3.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model=SARIMAX(train,order=(0,1,1),seasonal_order=(0,1,1,52)).fit()

# %%
print(model.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          Sentiment   No. Observations:                  140
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 52)   Log Likelihood                 240.972
# Date:                            Tue, 13 Dec 2022   AIC                           -475.945
# Time:                                    13:23:48   BIC                           -468.547
# Sample:                                10-03-2010   HQIC                          -472.966
#                                      - 06-02-2013
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8041      0.073    -11.085      0.000      -0.946      -0.662
# ma.S.L52      -0.8680      1.401     -0.620      0.536      -3.614       1.878
# sigma2         0.0001      0.000      0.750      0.453      -0.000       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):                 0.17
# Prob(Q):                              0.79   Prob(JB):                         0.92
# Heteroskedasticity (H):               0.36   Skew:                             0.10
# Prob(H) (two-sided):                  0.01   Kurtosis:                         2.90
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
sarima_predict=model.predict(len(train),len(train)+len(test)-1)
sarima_forecast=model.predict(len(month),len(month)+104)

# %%
month['Sentiment']
# Out:
# Time
# 2010-10-03 00:00:00+00:00    0.882353
# 2010-10-10 00:00:00+00:00    0.899510
# 2010-10-17 00:00:00+00:00    0.914692
# 2010-10-24 00:00:00+00:00    0.886918
# 2010-10-31 00:00:00+00:00    0.910891
#                                ...
# 2014-06-29 00:00:00+00:00    0.925357
# 2014-07-06 00:00:00+00:00    0.967818
# 2014-07-13 00:00:00+00:00    0.963445
# 2014-07-20 00:00:00+00:00    0.974599
# 2014-07-27 00:00:00+00:00    0.944310
# Freq: W-SUN, Name: Sentiment, Length: 200, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(test,color='r',label='actul')
plt.plot(sarima_forecast,color='g',label=' forecast')
plt.ylabel('sentiment',fontsize=(20))
plt.xlabel('time',fontsize=(20))

plt.legend()
plt.show()
